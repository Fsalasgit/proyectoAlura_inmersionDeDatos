# %% [markdown]
# <a href="https://colab.research.google.com/github/Fsalasgit/proyectoAlura_inmersionDeDatos/blob/clase_03/INMERSION_DATOS_AULA_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Inmersion de datos</h1>
#
# <h3>Desarollado por <strong>Franco Exequiel Salas</strong><h3>
#
# <a href="https://ar.linkedin.com/in/franco-exequiel-salas-bb639a208" target="_blank">Linkedin</a>
#
# <a href="https://github.com/Fsalasgit" target="_blank">Git hub</a>

# %% [markdown]
# ## **AULA 1**

# %%
## Montado del drive

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## importado de pandas (se usa 'pd' por convención) y asignación en variable inmuebles

import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/inmuebles_bogota.csv')

inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
## Tamaño del DF


inmuebles.shape
# Out:
# (9520, 8)

# %%
## Detalles de columnas

inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
## Correccion de posibles atributos que causen errores


columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                               Descripcion  Habitaciones  \
# 5770  Apartamento          Apartamento en venta en Cedritos             3
# 7567  Apartamento  Apartamento en venta en Lagos De Cordoba             3
# 6753         Casa           Casa en venta en Barrios Unidos             3
# 7933  Apartamento    Apartamento en venta en Ciudad Bolívar             3
# 6028         Casa              Casa en venta en Teusaquillo             8
# 7673         Casa                 Casa en venta en Fontibón             6
# 2045  Apartamento    Apartamento en venta en Barrios Unidos             3
# 5167  Apartamento           Apartamento en venta en Mazuren             3
# 1540  Apartamento    Apartamento en venta en Ciudad Salitre             3
# 258   Apartamento           Apartamento en venta en Tintala             2
#
#       Banos  Area            Barrio  \
# 5770      4   127          Cedritos
# 7567      4   188  Lagos De Cordoba
# 6753      5   342    Barrios Unidos
# 7933      1    50    Ciudad Bolívar
# 6028      7   320       Teusaquillo
# 7673      4   257          Fontibón
# 2045      2    66    Barrios Unidos
# 5167      2    76           Mazuren
# 1540      2    63    Ciudad Salitre
# 258       2    54           Tintala
#
#                                                     UPZ            Valor
# 5770                                            Usaquén    $ 380.000.000
# 7567                                               Niza  $ 1.080.000.000
# 6753                                          Los Andes  $ 2.550.000.000
# 7933  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...    $ 200.000.000
# 6028                                        Teusaquillo    $ 996.000.000
# 7673                                           Fontibón    $ 700.000.000
# 2045                                          Los Andes    $ 235.000.000
# 5167                                           El Prado    $ 340.000.000
# 1540                            Ciudad Salitre Oriental    $ 495.000.000
# 258                                             Tintala    $ 232.500.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
## buqueda por indice
## En este caso buscar desde el indice 300 a 304 (no incluye 305)

inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
## para saber el valor de un inmueble por indice en particular


inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
## devuelve un true y un false para indicar si en el atributo cumple con la condicion

(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
## Aplicamos la suma

sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
## Guardamos dentro de una variable la condicion

inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
inmuebles_chico
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
## Guardamor el resultado y filtramos como parametro que cumpla la condicion
## tambien fucionaria con la siguiente sintaxis:
#chico_reservado = inmuebles[(inmuebles.Barrio == 'Chico Reservado')]

chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
mediaAreaChicoReservado = chico_reservado.Area.mean()
mediaAreaTotal = inmuebles.Area.mean()

print(f'la media del area de chico resevado es: "{mediaAreaChicoReservado}" mientras que del general es "{mediaAreaTotal}" .')
# Out:
# la media del area de chico resevado es: "142.78666666666666" mientras que del general es "146.66470588235293" .

# %%
## cantidad de barrios

len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
## primero guardamos en una varible la cantidad de inmuebles y luego mostramos los primeros 10
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# <h2>DESAFIO</h2>
#
# <ol>
#   <li>Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.</li>
#   <li>Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.</li>
# </ol>

# %%
top_10_barrios = inmuebles_barrio.nlargest(10)
top_10_barrios
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
# Barrios Unidos         473
# Engativa               462
# Suba                   443
# Santa Barbara          438
# Chapinero              332
# Name: Barrio, dtype: int64

# %%
mediaUsaquen = inmuebles[(inmuebles.Barrio == 'Usaquén')].Area.mean()
mediaZonaNoroccidental = inmuebles[(inmuebles.Barrio == 'Zona Noroccidental')].Area.mean()
mediaBosa = inmuebles[(inmuebles.Barrio == 'Bosa')].Area.mean()
mediaKennedy = inmuebles[(inmuebles.Barrio == 'Kennedy')].Area.mean()
mediaCedritos = inmuebles[(inmuebles.Barrio == 'Cedritos')].Area.mean()
mediaBarriosUnidos = inmuebles[(inmuebles.Barrio == 'Barrios Unidos')].Area.mean()
mediaEngativa = inmuebles[(inmuebles.Barrio == 'Engativa')].Area.mean()
mediaSuba = inmuebles[(inmuebles.Barrio == 'Suba')].Area.mean()
mediaSantaBarbara = inmuebles[(inmuebles.Barrio == 'Santa Barbara')].Area.mean()
mediaChapinero = inmuebles[(inmuebles.Barrio == 'Chapinero')].Area.mean()

# %%
acumuladoMedia = {
    "Usaquén"  : mediaUsaquen,
    "Zona Noroccidental" : mediaZonaNoroccidental,
    "Bosa " : mediaBosa,
    "Kennedy  " : mediaKennedy,
    "Cedritos " : mediaCedritos,
    "Barrios Unidos " : mediaBarriosUnidos,
    "Engativa " : mediaEngativa,
    "Suba" : mediaSuba,
    "Santa Barbara" : mediaSantaBarbara,
    "Chapinero " : mediaChapinero
    }
print('A continucion una lista con todos los valores:')
acumuladoMedia
# Out:
# A continucion una lista con todos los valores:
# {'Usaquén': 134.04615384615386,
#  'Zona Noroccidental': 135.78563283922463,
#  'Bosa ': 59.217317487266556,
#  'Kennedy  ': 104.37181663837012,
#  'Cedritos ': 96.95126353790614,
#  'Barrios Unidos ': 185.6215644820296,
#  'Engativa ': 129.45454545454547,
#  'Suba': 139.08577878103839,
#  'Santa Barbara': 124.86986301369863,
#  'Chapinero ': 244.72289156626505}

# %%
# Ordenar el diccionario de mayor a menor según los valores
acumuladoMedia_ordenado = dict(sorted(acumuladoMedia.items(), key=lambda x: x[1], reverse=True))

# Mostrar el diccionario ordenado
print('Diccionario ordenado de mayor a menor area:')
print(acumuladoMedia_ordenado)
# Out:
# Diccionario ordenado de mayor a menor area:
# {'Chapinero ': 244.72289156626505, 'Barrios Unidos ': 185.6215644820296, 'Suba': 139.08577878103839, 'Zona Noroccidental': 135.78563283922463, 'Usaquén': 134.04615384615386, 'Engativa ': 129.45454545454547, 'Santa Barbara': 124.86986301369863, 'Kennedy  ': 104.37181663837012, 'Cedritos ': 96.95126353790614, 'Bosa ': 59.217317487266556}

# %%
# Crear un DataFrame a partir del diccionario
df_acumuladoMedia = pd.DataFrame(list(acumuladoMedia_ordenado.items()), columns=['Barrio', 'Media'])

# Trazar un gráfico de barras utilizando pandas
df_acumuladoMedia.plot.bar(x='Barrio', y='Media', legend=False)
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# Cantidad por tipo de inmueble

# %%
inmuebles.Tipo.value_counts()
# Out:
# Apartamento            7327
# Casa                   2043
# Oficina/Consultorio      60
# Local                    38
# Edificio                 22
# Bodega                   13
# Finca                    11
# Lote                      6
# Name: Tipo, dtype: int64

# %% [markdown]
# Cantidad de UPZ

# %%
inmuebles.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
inmuebleValorMaximo = inmuebles.Valor.max()
inmuebleValorMinimo = inmuebles.Valor.min()

# %%
inmuebleValorMaximo
# Out:
# '$ 999.000.000'

# %%
inmuebleValorMinimo
# Out:
# '$ 1.000.000.000'

# %%
inmueblemayorHabitaciones = inmuebles.Habitaciones.max()
inmuebleMenorHabitaciones = inmuebles.Habitaciones.min()

# %%
## Deteccion de dato atípico.

inmueblemayorHabitaciones
# Out:
# 110

# %%
inmuebleMenorHabitaciones
# Out:
# 1

# %% [markdown]
# ## **AULA 2**

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 2859  Apartamento             Apartamento en venta en Usaquén             3
# 8175  Apartamento           Apartamento en venta en Pasadena              3
# 2334  Apartamento                Apartamento en venta en Suba             3
# 8560  Apartamento      Apartamento en venta en Ciudad Bolívar             3
# 356   Apartamento  Apartamento en venta en Zona Noroccidental             3
#
#       Banos  Area              Barrio  \
# 2859      2    82             Usaquén
# 8175      3   109           Pasadena
# 2334      2    66                Suba
# 8560      2    62      Ciudad Bolívar
# 356       2    58  Zona Noroccidental
#
#                                                     UPZ          Valor
# 2859                                            Usaquén  $ 450.000.000
# 8175                                                NaN  $ 515.000.000
# 2334                                               Suba  $ 249.000.000
# 8560  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...  $ 200.000.000
# 356                  CHAPINERO: Pardo Rubio + Chapinero  $ 311.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# Podemos observar que el atributo valor está como Object *("$" , "num" , ".")* y necesitamos cambiarlo a numero

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %% [markdown]
# Por lo que si intentamos sumar nos cancatenaría

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
## Separamos en dos cumplumnas nuevas

valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 703   Apartamento      Apartamento en venta en Cantagallo             2
# 5531         Casa            Casa en venta en Pontevedra              4
# 8993  Apartamento  Apartamento en venta en Ciudad Bolívar             3
#
#       Banos  Area          Barrio  \
# 703       2    60      Cantagallo
# 5531      5   208     Pontevedra
# 8993      1    50  Ciudad Bolívar
#
#                                                     UPZ          Valor Moneda  \
# 703                                            Britalia  $ 386.990.000      $
# 5531                                        La Floresta  $ 850.000.000      $
# 8993  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...  $ 170.000.000      $
#
#            Precio
# 703   386.990.000
# 5531  850.000.000
# 8993  170.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Precio continúa siendo tipo string

# %%
## sacamos los "."

inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
## Convertimos al precio a tipo float y lo dividimos en 1.000.000 para no tener números tan grandes.

inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
## Con el metodo set option colocaremos 2 decimales.

pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
## Con bins le damos la frecuencia

inmuebles['Precio_Millon'].plot.hist(bins=80)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribución de Valores de los inmuebles en Bogotá')
plt.xlim((50,1000))
plt.savefig('/content/drive/MyDrive/Inmersion_a_base_de_datos/valor_inmuebles.png',format='png')
plt.show()

# %% [markdown]
# **Desafíos**
#
# 1.   Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información)
# 2.   Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Area', kde=True, hue='Tipo')
grafica.set_title('Distribución de Area de los inmuebles en Bogotá')
plt.ylim((0,120))
plt.show()

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Habitaciones', kde=True, hue='Tipo')
grafica.set_title('Distribución de Habitaciones de los inmuebles en Bogotá')
plt.ylim((0,600))
plt.show()

# %%
inmuebles['Precio_m2'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
#  11  Precio_m2      9520 non-null   float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 892.6+ KB

# %%
inmuebles[['Barrio','Precio_m2']].describe()
# Out:
#        Precio_m2
# count    9520.00
# mean        5.01
# std         2.37
# min         0.01
# 25%         3.48
# 50%         4.67
# 75%         6.12
# max        90.00

# %% [markdown]
# ## **AULA 3**

# %%
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Precio_m2  \
# 0    $ 360.000.000      $   360000000         360.00       5.14
# 1    $ 670.000.000      $   670000000         670.00       3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00       7.78
#
#    Valor_m2_Millon
# 0             5.14
# 1             3.94
# 2             7.78

# %%
inmuebles.groupby('Barrio').mean()
# Out:
# <ipython-input-50-7fb844af9b3c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmuebles.groupby('Barrio').mean()
#                     Habitaciones  Banos   Area  Precio_Millon  Precio_m2  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00       5.98
# Alhambra                    3.00   2.94 190.41         752.35       4.33
# Andes Norte                 3.00   2.86 124.86         709.57       6.05
# Antonio Nariño              4.31   2.50 163.06         459.22       3.53
# Barrancas                   2.87   2.13  70.20         314.13       4.42
# ...                          ...    ...    ...            ...        ...
# Villa Maria                 4.69   3.69 207.15         402.85       2.04
# Villas De Granada           3.45   2.32  86.59         282.30       3.17
# Villemar                    2.94   2.06  76.89         303.83       3.99
# Zona Franca                 2.00   1.00  54.00         160.00       2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81       4.62
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                       4.33
# Andes Norte                    6.05
# Antonio Nariño                 3.53
# Barrancas                      4.42
# ...                             ...
# Villa Maria                    2.04
# Villas De Granada              3.17
# Villemar                       3.99
# Zona Franca                    2.96
# Zona Noroccidental             4.62
#
# [149 rows x 6 columns]

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
# <ipython-input-51-45bba8259daf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datos_barrio = inmuebles.groupby('Barrio').sum()
#                     Habitaciones  Banos    Area  Precio_Millon  Precio_m2  \
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00      73.56
# Andes Norte                   21     20     874        4967.00      42.35
# Antonio Nariño               207    120    7827       22042.65     169.47
# Barrancas                     43     32    1053        4712.00      66.24
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00      26.58
# Villas De Granada             76     51    1905        6210.62      69.71
# Villemar                      53     37    1384        5469.00      71.81
# Zona Franca                    2      1      54         160.00       2.96
# Zona Noroccidental          2778   2204  119084      544453.06    4049.16
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# Barrancas                     66.24
# ...                             ...
# Villa Maria                   26.58
# Villas De Granada             69.71
# Villemar                      71.81
# Zona Franca                    2.96
# Zona Noroccidental          4049.16
#
# [149 rows x 6 columns]

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  Precio_m2  \
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00      73.56
# Andes Norte                   21     20     874        4967.00      42.35
# Antonio Nariño               207    120    7827       22042.65     169.47
# Barrancas                     43     32    1053        4712.00      66.24
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00      26.58
# Villas De Granada             76     51    1905        6210.62      69.71
# Villemar                      53     37    1384        5469.00      71.81
# Zona Franca                    2      1      54         160.00       2.96
# Zona Noroccidental          2778   2204  119084      544453.06    4049.16
#
#                     Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# Andes Norte                   42.35             5.68
# Antonio Nariño               169.47             2.82
# Barrancas                     66.24             4.47
# ...                             ...              ...
# Villa Maria                   26.58             1.94
# Villas De Granada             69.71             3.26
# Villemar                      71.81             3.95
# Zona Franca                    2.96             2.96
# Zona Noroccidental          4049.16             4.57
#
# [149 rows x 7 columns]

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Precio_m2  \
# 0    $ 360.000.000      $   360000000         360.00       5.14
# 1    $ 670.000.000      $   670000000         670.00       3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00       7.78
# 3    $ 890.000.000      $   890000000         890.00       5.78
# 4    $ 970.000.000      $   970000000         970.00       7.58
#
#    Valor_m2_Millon  Valor_m2_Barrio
# 0             5.14             4.57
# 1             3.94             3.40
# 2             7.78             8.10
# 3             5.78             5.66
# 4             7.58             6.29

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2  Valor_m2_Millon  Valor_m2_Barrio
# 0         5.98             5.98             5.98
# 1        73.56            73.56             3.95
# 2        42.35            42.35             5.68
# 3       169.47           169.47             2.82
# 4        66.24            66.24             4.47
# ..         ...              ...              ...
# 144      26.58            26.58             1.94
# 145      69.71            69.71             3.26
# 146      71.81            71.81             3.95
# 147       2.96             2.96             2.96
# 148    4049.16          4049.16             4.57
#
# [149 rows x 8 columns]

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2  Valor_m2_Millon  Valor_m2_Barrio
# 5      2070.61          2070.61             2.96
# 10     1654.36          1654.36             2.68
# 22     2853.23          2853.23             5.03
# 24     2466.03          2466.03             4.58
# 50     1795.71          1795.71             2.89
# 63     2127.66          2127.66             3.38
# 125    2701.88          2701.88             5.85
# 132    2000.72          2000.72             4.32
# 138    6334.04          6334.04             5.66
# 148    4049.16          4049.16             4.57

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x="Barrio", y="Valor_m2_Barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Identificación (Capítulo A).csv', sep = ';',encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# 1                            Santa Isabel  17,8555889419101
# 2  SANTA FE: Las Nieves + Sagrado Corazón  10,0286103658331
# 3   USAQUÉN: Country Club + Santa Bárbara  28,6502122142802
# 4   USAQUÉN: Country Club + Santa Bárbara  24,4684068319009

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %%
## tomamos 11001 que hace referencia a un destino en particular de bogota (sin zona rural)
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Datos de la vivenda y su entorno (Capítulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Educación (Capitulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-68-bdf0fb77e1d7>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-68-bdf0fb77e1d7>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-68-bdf0fb77e1d7>:4: DtypeWarning: Columns (26,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Educación (Capitulo H).csv',sep=';',encoding='latin-1')
# <ipython-input-68-bdf0fb77e1d7>:5: DtypeWarning: Columns (114,117,122,126,164,166,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_l = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
# <ipython-input-68-bdf0fb77e1d7>:6: DtypeWarning: Columns (27,58,60,62,64,66,104,114,120,124,126,129,131,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_k = pd.read_csv('/content/drive/MyDrive/Inmersion_a_base_de_datos/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')

# %%
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# Out:
# <ipython-input-71-94d5bdd5b9a5>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')

# %%
datos_dane.shape
# Out:
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB
